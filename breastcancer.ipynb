# %% [markdown]
# <a href="https://colab.research.google.com/github/G-Karishni/Pattern_Recognition/blob/main/breastcancer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***Breast Cancer (Wisconsin) Dataset***
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Importing the libraries

# %%
                                                                                     #G.Karishni (ECE19116)
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt

# %% [markdown]
# Upload dataset

# %%
from google.colab import files  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dcef773f-e4aa-43b2-b195-7e3dd33424fe" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dcef773f-e4aa-43b2-b195-7e3dd33424fe">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving breastcancer.csv to breastcancer.csv

# %%
dataset = pd.read_csv("breastcancer.csv")
dataset.head()
# Out:
#          id diagnosis  ...  fractal_dimension_worst  Unnamed: 32
# 0    842302         M  ...                  0.11890          NaN
# 1    842517         M  ...                  0.08902          NaN
# 2  84300903         M  ...                  0.08758          NaN
# 3  84348301         M  ...                  0.17300          NaN
# 4  84358402         M  ...                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# #Classes
#
#
# 1.   malignant
# 2.   benign

# %% [markdown]
# #Features
#
#
# 1.   radius
# 2.   texture
# 3.   perimeter
# 4.   area
# 5.   smoothness
# 6.   compactness
# 7.   concavity
# 8.   concave_points
# 9.   symmetry
# 10.  fractal_dimension .... etc

# %%
dataset = dataset.drop(["id"], axis = 1)
dataset = dataset.drop(["Unnamed: 32"], axis = 1)
dataset.head(3)
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
#
# [3 rows x 31 columns]

# %%
M = dataset[dataset.diagnosis == "M"]
M.head(5)
# Out:
#   diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 0         M        17.99  ...          0.4601                  0.11890
# 1         M        20.57  ...          0.2750                  0.08902
# 2         M        19.69  ...          0.3613                  0.08758
# 3         M        11.42  ...          0.6638                  0.17300
# 4         M        20.29  ...          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
B = dataset[dataset.diagnosis == "B"]
B.head(5)
# Out:
#    diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst
# 19         B       13.540  ...          0.2977                  0.07259
# 20         B       13.080  ...          0.3184                  0.08183
# 21         B        9.504  ...          0.2450                  0.07773
# 37         B       13.030  ...          0.1987                  0.06169
# 46         B        8.196  ...          0.3105                  0.07409
#
# [5 rows x 31 columns]

# %%
plt.title("Malignant vs Benign Tumor")
plt.xlabel("Radius Mean")
plt.ylabel("Texture Mean")
plt.scatter(M.radius_mean, M.texture_mean, color = "red", label = "Malignant", alpha = 0.3)
plt.scatter(B.radius_mean, B.texture_mean, color = "lime", label = "Benign", alpha = 0.3)
plt.legend()
plt.show()

# %%
dataset.diagnosis = [1 if i == "M" else 0 for i in dataset.diagnosis]
X = dataset.drop(["diagnosis"], axis = 1)
y = dataset.diagnosis.values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
print("Naive Bayes score: ",nb.score(X_test, y_test))
# Out:
# Naive Bayes score:  0.9415204678362573
